# %% [markdown]
# # Lab | Web Scraping Single Page (GNOD part 1)

# %%
from bs4 import BeautifulSoup

# %%
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
# 3. download html with a get request
response = requests.get(url)

# %%
# Check if the request was successful (status code 200)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
# soup

# %%
song_elements = soup.find_all('div',class_ ='chart-content')

# %%
for i, element in enumerate(song_elements):
        title = element.find('cite', class_='title').text.strip()
        artist = element.find('em', class_='artist').text.strip()
        genre = element.find('ul').find('li').text.strip()
      
        print(f"{i + 1}. {title} - {artist} - {genre}")
# Out:
# 1. TEXAS HOLD 'EM - Beyoncé - Genre: Country
# 2. Lose Control - Teddy Swims - Genre: Pop
# 3. Beautiful Things - Benson Boone - Genre: Pop
# 4. Flowers - Miley Cyrus - Genre: Pop
# 5. Turn the Lights Back On - Billy Joel - Genre: Pop
# 6. Don't Let the Old Man In - Toby Keith - Genre: Country
# 7. Lovin On Me - Jack Harlow - Genre: Hip-Hop / Rap
# 8. Selfish - Justin Timberlake - Genre: Pop
# 9. Sorrys & Ferraris - Polo G - New Release
# 10. TEXAS HOLD 'EM - Beyoncé - Genre: Country
# 11. I Remember Everything (feat. Kacey Musgraves) - Zach Bryan - Genre: Country
# 12. Made For Me - Muni Long - Genre: R&B / Soul
# 13. Houdini - Dua Lipa - Genre: Pop
# 14. Training Season - Dua Lipa - New Release
# 15. Fast Car - Luke Combs - Genre: Country
# 16. Fast Car - Tracy Chapman - Genre: Singer/Songwriter
# 17. Live Like You Were Dying - Tim McGraw - Genre: Country
# 18. Save Me - Jelly Roll - Genre: Rap
# 19. Let's Go - Key Glock - Genre: Hip-Hop / Rap
# 20. Yeah! (feat. Lil Jon & Ludacris) - USHER - Genre: R&B / Soul
# 21. Lil Boo Thang - Paul Russell - Genre: Pop
# 22. Cruel Summer - Taylor Swift - Genre: Pop
# 23. 16 CARRIAGES - Beyoncé - Genre: Country
# 24. Where the Wild Things Are - Luke Combs - Genre: Country
# 25. Until I Found You - Stephen Sanchez - Genre: Singer/Songwriter
# 26. Need a Favor - Jelly Roll - Genre: Country
# 27. Country's Cool Again - Lainey Wilson - New Release
# 28. In Case You Didn't Know - Brett Young - Genre: Country
# 29. Spicy Margarita - Jason Derulo & Michael Bublé - Genre: Pop
# 30. You Are the Reason - Calum Scott - Genre: Pop
# 31. yes, and? - Ariana Grande & Mariah Carey - New Release
# 32. Three Little Birds - Bob Marley & The Wailers - Genre: Reggae
# 33. Until I Found You (Em Beihold Version) - Stephen Sanchez & Em Beihold - Genre: Singer/Songwriter
# 34. Powerful Women - Pitbull & Dolly Parton - New Release
# 35. Water - Tyla - Genre: Pop
# 36. White Horse - Chris Stapleton - Genre: Country
# 37. Murder On the Dancefloor (Radio Edit) - Sophie Ellis-Bextor - Genre: Dance
# 82. Bulletproof - Nate Smith - Genre: Country
# 83. redrum - 21 Savage - Genre: Hip-Hop / Rap
# 84. Lead Me Home - Jamey Johnson - Genre: Country
# 85. Good Days - SZA - Genre: R&B / Soul
# 86. Unwritten - Natasha Bedingfield - Genre: Pop
# 87. Dance You Outta My Head - Cat Janice - Genre: Pop
# 88. Life With You - Kelsey Hart - Genre: Country
# 89. Strangers - Kenya Grace - Genre: Dance
# 90. Everybody (feat. Lil Uzi Vert) - Nicki Minaj - Genre: Hip-Hop / Rap
# 91. Can't Get Enough - Jennifer Lopez - Genre: Pop
# 92. Give In to Me - Garrett Hedlund & Leighton Meester - Genre: Soundtrack
# 93. ...Ready For It? - Taylor Swift - Genre: Pop
# 94. How Do You Like Me Now?! - Toby Keith - Genre: Country
# 95. Purple Irises - Gwen Stefani & Blake Shelton - Genre: Pop
# 96. Tell It To My Heart - Cash Cash & Taylor Dayne - Genre: Dance
# 97. We Takin' Over (feat. Akon, T.I., Rick Ross, Fat Joe, Baby & Lil' Wayne) - DJ Khaled - Genre: Hip-Hop / Rap
# 98. Used To Be Young - Miley Cyrus - Genre: Pop
# 99. Heart Like a Truck - Lainey Wilson - Genre: Country
# 100. greedy - Tate McRae - Genre: Pop

# %%
titles = []
artists = []
genres = []
for i, element in enumerate(song_elements):
        title = element.find('cite', class_='title').text.strip()
        titles.append(title)
        artist = element.find('em', class_='artist').text.strip()
        artists.append(artist)
        genre = element.find('ul').find('li').text.strip()
        genres.append(genre)
        print(f"{title} - {artist} - {genre}")
        #data.append('title', 'artist', 'genre'])
# Out:
# TEXAS HOLD 'EM - Beyoncé - Genre: Country
# Lose Control - Teddy Swims - Genre: Pop
# Beautiful Things - Benson Boone - Genre: Pop
# Flowers - Miley Cyrus - Genre: Pop
# Turn the Lights Back On - Billy Joel - Genre: Pop
# Don't Let the Old Man In - Toby Keith - Genre: Country
# Lovin On Me - Jack Harlow - Genre: Hip-Hop / Rap
# Selfish - Justin Timberlake - Genre: Pop
# Sorrys & Ferraris - Polo G - New Release
# TEXAS HOLD 'EM - Beyoncé - Genre: Country
# I Remember Everything (feat. Kacey Musgraves) - Zach Bryan - Genre: Country
# Made For Me - Muni Long - Genre: R&B / Soul
# Houdini - Dua Lipa - Genre: Pop
# Training Season - Dua Lipa - New Release
# Fast Car - Luke Combs - Genre: Country
# Fast Car - Tracy Chapman - Genre: Singer/Songwriter
# Live Like You Were Dying - Tim McGraw - Genre: Country
# Save Me - Jelly Roll - Genre: Rap
# Let's Go - Key Glock - Genre: Hip-Hop / Rap
# Yeah! (feat. Lil Jon & Ludacris) - USHER - Genre: R&B / Soul
# Lil Boo Thang - Paul Russell - Genre: Pop
# Cruel Summer - Taylor Swift - Genre: Pop
# 16 CARRIAGES - Beyoncé - Genre: Country
# Where the Wild Things Are - Luke Combs - Genre: Country
# Karma - Taylor Swift - Genre: Pop
# Stick Season - Noah Kahan - Genre: Alternative
# 23 - Chayce Beckham - Genre: Country
# EASY - LE SSERAFIM - New Release
# Praise (feat. Brandon Lake, Chris Brown & Chandler Moore) - Elevation Worship - Genre: Christian & Gospel
# The Door - Teddy Swims - Genre: Pop
# TRUCK BED - HARDY - Genre: Country
# We Are the World - U.S.A. for Africa - Genre: Rock
# You Need To Calm Down - Taylor Swift - Genre: Pop
# A Symptom Of Being Human - Shinedown - Genre: Hard Rock
# Bulletproof - Nate Smith - Genre: Country
# redrum - 21 Savage - Genre: Hip-Hop / Rap
# Lead Me Home - Jamey Johnson - Genre: Country
# Good Days - SZA - Genre: R&B / Soul
# Unwritten - Natasha Bedingfield - Genre: Pop
# Dance You Outta My Head - Cat Janice - Genre: Pop
# Life With You - Kelsey Hart - Genre: Country
# Strangers - Kenya Grace - Genre: Dance
# Everybody (feat. Lil Uzi Vert) - Nicki Minaj - Genre: Hip-Hop / Rap
# Can't Get Enough - Jennifer Lopez - Genre: Pop
# Give In to Me - Garrett Hedlund & Leighton Meester - Genre: Soundtrack
# ...Ready For It? - Taylor Swift - Genre: Pop
# How Do You Like Me Now?! - Toby Keith - Genre: Country
# Purple Irises - Gwen Stefani & Blake Shelton - Genre: Pop
# Tell It To My Heart - Cash Cash & Taylor Dayne - Genre: Dance
# We Takin' Over (feat. Akon, T.I., Rick Ross, Fat Joe, Baby & Lil' Wayne) - DJ Khaled - Genre: Hip-Hop / Rap
# Used To Be Young - Miley Cyrus - Genre: Pop
# Heart Like a Truck - Lainey Wilson - Genre: Country
# greedy - Tate McRae - Genre: Pop

# %%
presis_df = pd.DataFrame({"title":titles,
                          "artist":artists,
                          "genre": genres})
presis_df
# Out:
#                                                 title  \
# 0                                      TEXAS HOLD 'EM
# 1                                        Lose Control
# 2                                    Beautiful Things
# 3                                             Flowers
# 4                             Turn the Lights Back On
# ..                                                ...
# 95                                Tell It To My Heart
# 96  We Takin' Over (feat. Akon, T.I., Rick Ross, F...
# 97                                   Used To Be Young
# 98                                 Heart Like a Truck
# 99                                             greedy
#
#                       artist                 genre
# 0                    Beyoncé        Genre: Country
# 1                Teddy Swims            Genre: Pop
# 2               Benson Boone            Genre: Pop
# 3                Miley Cyrus            Genre: Pop
# 4                 Billy Joel            Genre: Pop
# ..                       ...                   ...
# 95  Cash Cash & Taylor Dayne          Genre: Dance
# 96                 DJ Khaled  Genre: Hip-Hop / Rap
# 97               Miley Cyrus            Genre: Pop
# 98             Lainey Wilson        Genre: Country
# 99                Tate McRae            Genre: Pop
#
# [100 rows x 3 columns]

# %%
import re
from datetime import datetime

if not song_elements:
    print("No song elements found. Please check if the website structure has changed.")
    exit()

data = []
for i, element in enumerate(song_elements):
    title = element.find('cite', class_='title').text.strip()
    artist = element.find('em', class_='artist').text.strip()

    # Extracting genre
    genre = "Genre not found"
    ul_tag = element.find('ul')
    if ul_tag:
        for li_tag in ul_tag.find_all('li'):
            if 'Genre' in li_tag.text:
                genre = li_tag.text.strip().replace('Genre:', '')
                break
                
    # Extracting release date using regular expression
    release_date_text = ""
    release_date_match = re.search(r'Release Date: (\w+ \d{1,2}, \d{4})', element.get_text())
    if release_date_match:
        release_date_text = release_date_match.group(1)
        
        # Convert release date to date format
        release_date = datetime.strptime(release_date_text, "%B %d, %Y").strftime("%d/%m/%Y")

    data.append([title, artist, genre, release_date])

df = pd.DataFrame(data, columns=['title', 'artist', 'genre', 'release_date'])
display(df)
# Out:
#                                                 title  \
# 0                                      TEXAS HOLD 'EM
# 1                                        Lose Control
# 2                                    Beautiful Things
# 3                                             Flowers
# 4                             Turn the Lights Back On
# ..                                                ...
# 95                                Tell It To My Heart
# 96  We Takin' Over (feat. Akon, T.I., Rick Ross, F...
# 97                                   Used To Be Young
# 98                                 Heart Like a Truck
# 99                                             greedy
#
#                       artist           genre release_date
# 0                    Beyoncé         Country   11/02/2024
# 1                Teddy Swims             Pop   23/06/2023
# 2               Benson Boone             Pop   19/01/2024
# 3                Miley Cyrus             Pop   12/01/2023
# 4                 Billy Joel             Pop   01/02/2024
# ..                       ...             ...          ...
# 95  Cash Cash & Taylor Dayne           Dance   15/09/2023
# 96                 DJ Khaled   Hip-Hop / Rap   27/03/2007
# 97               Miley Cyrus             Pop   25/08/2023
# 98             Lainey Wilson         Country   20/05/2022
# 99                Tate McRae             Pop   15/09/2023
#
# [100 rows x 4 columns]

# %% [markdown]
# # Lab | Web Scraping Single Page (GNOD part 2)¶

# %%
import random

# %%
# Function to recommend a random song if the input song is found in the DataFrame
def recommend_song(song_title):
    # Check if the song is in the DataFrame (case insensitive)
    if df['title'].str.lower().str.contains(song_title.lower()).any():
        # Get a random index that is not the index of the input song
        random_index = df[df['title'].str.lower() != song_title.lower()].sample().index[0]
        # Get the random song and artist
        random_song = df.loc[random_index, 'title']
        random_artist = df.loc[random_index, 'artist']
        return f"Thank you for the input and now we recommend \"{random_song}\" by {random_artist}"
    else:
        return "Thank you for the input but we currently have no recommendation for this song."

# Loop to recommend songs for 5 times
for i in range(5):
    input_song = input("Enter a song title: ")
    recommendation = recommend_song(input_song)
    print(recommendation)
# Out:
# Enter a song title: flowers
# Thank you for the input and now we recommend "Good Day" by Forrest Frank
# Enter a song title: Flowers
# Thank you for the input and now we recommend "Fast Car" by Tracy Chapman
# Enter a song title: flower
# Thank you for the input and now we recommend "Dance You Outta My Head" by Cat Janice
# Enter a song title: greedy
# Thank you for the input and now we recommend "EASY" by LE SSERAFIM
# Enter a song title: no greedy
# Thank you for the input but we currently have no recommendation for this song.
