# %% [markdown]
# # Lab | Web Scraping Single Page (GNOD part 1)

# %%
from bs4 import BeautifulSoup

# %%
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
# 3. download html with a get request
response = requests.get(url)

# %%
# Check if the request was successful (status code 200)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
# soup

# %%
song_elements = soup.find_all('div',class_ ='chart-content')

# %%
for i, element in enumerate(song_elements):
        title = element.find('cite', class_='title').text.strip()
        artist = element.find('em', class_='artist').text.strip()
        genre = element.find('ul').find('li').text.strip()
      
        print(f"{i + 1}. {title} - {artist} - {genre}")
# Out:
# 1. TEXAS HOLD 'EM - Beyoncé - Genre: Country
# 2. Beautiful Messes - Hillary Scott & The Scott Family - Genre: Country
# 3. Lose Control - Teddy Swims - Genre: Pop
# 4. Beautiful Things - Benson Boone - Genre: Pop
# 5. Flowers - Miley Cyrus - Genre: Pop
# 6. TEXAS HOLD 'EM - Beyoncé - Genre: Country
# 7. Lovin On Me - Jack Harlow - Genre: Hip-Hop / Rap
# 8. Turn the Lights Back On - Billy Joel - Genre: Pop
# 9. Don't Let the Old Man In - Toby Keith - Genre: Country
# 10. Selfish - Justin Timberlake - Genre: Pop
# 11. I Remember Everything (feat. Kacey Musgraves) - Zach Bryan - Genre: Country
# 12. Made For Me - Muni Long - Genre: R&B / Soul
# 13. Fast Car - Luke Combs - Genre: Country
# 14. Houdini - Dua Lipa - Genre: Pop
# 15. Live Like You Were Dying - Tim McGraw - Genre: Country
# 16. Where the Wild Things Are - Luke Combs - Genre: Country
# 17. Lil Boo Thang - Paul Russell - Genre: Pop
# 18. Training Season - Dua Lipa - New Release
# 19. Save Me - Jelly Roll - Genre: Rap
# 20. Fast Car - Tracy Chapman - Genre: Singer/Songwriter
# 21. 16 CARRIAGES - Beyoncé - Genre: Country
# 22. Until I Found You - Stephen Sanchez - Genre: Singer/Songwriter
# 23. Yeah! (feat. Lil Jon & Ludacris) - USHER - Genre: R&B / Soul
# 24. Cruel Summer - Taylor Swift - Genre: Pop
# 25. Need a Favor - Jelly Roll - Genre: Country
# 26. You Are the Reason - Calum Scott - Genre: Pop
# 27. Sorrys & Ferraris - Polo G - New Release
# 28. Three Little Birds - Bob Marley & The Wailers - Genre: Reggae
# 29. Spicy Margarita - Jason Derulo & Michael Bublé - Genre: Pop
# 30. Powerful Women - Pitbull & Dolly Parton - New Release
# 31. White Horse - Chris Stapleton - Genre: Country
# 32. Save Me (with Lainey Wilson) - Jelly Roll - Genre: Country
# 33. Thinkin’ Bout Me - Morgan Wallen - Genre: Country
# 34. Murder On the Dancefloor (Radio Edit) - Sophie Ellis-Bextor - Genre: Dance
# 35. Country's Cool Again - Lainey Wilson - New Release
# 36. Should've Been a Cowboy - Toby Keith - Genre: Country
# 37. Good Day - Forrest Frank - Genre: Christian & Gospel
# 38. What Was I Made For? (From The Motion Picture "Barbie") - Billie Eilish - Genre: Alternative
# 39. Water - Tyla - Genre: Pop
# 40. Until I Found You (Em Beihold Version) - Stephen Sanchez & Em Beihold - Genre: Singer/Songwriter
# 41. Spin You Around (1/24) - Morgan Wallen - Genre: Country
# 42. Wildflowers and Wild Horses (Single Version) - Lainey Wilson - Genre: Country
# 43. In Case You Didn't Know - Brett Young - Genre: Country
# 44. A Country Boy Can Survive - Hank Williams, Jr. - Genre: Country
# 45. Hard to Love - Lee Brice - Genre: Country
# 46. Lovin On Me - Jack Harlow - Genre: Hip-Hop / Rap
# 95. HISS - Megan Thee Stallion - Genre: Hip-Hop / Rap
# 96. Leave a Light On - Papa Roach - Genre: Hard Rock
# 97. ...Ready For It? - Taylor Swift - Genre: Pop
# 98. The Painter - Cody Johnson - Genre: Country
# 99. Scared To Start - Michael Marcagi - Genre: Alternative
# 100. Unwritten - Natasha Bedingfield - Genre: Pop

# %%
titles = []
artists = []
genres = []
for i, element in enumerate(song_elements):
        title = element.find('cite', class_='title').text.strip()
        titles.append(title)
        artist = element.find('em', class_='artist').text.strip()
        artists.append(artist)
        genre = element.find('ul').find('li').text.strip()
        genres.append(genre)
        print(f"{title} - {artist} - {genre}")
        #data.append('title', 'artist', 'genre'])
# Out:
# TEXAS HOLD 'EM - Beyoncé - Genre: Country
# Beautiful Messes - Hillary Scott & The Scott Family - Genre: Country
# Lose Control - Teddy Swims - Genre: Pop
# Beautiful Things - Benson Boone - Genre: Pop
# Flowers - Miley Cyrus - Genre: Pop
# TEXAS HOLD 'EM - Beyoncé - Genre: Country
# Lovin On Me - Jack Harlow - Genre: Hip-Hop / Rap
# Turn the Lights Back On - Billy Joel - Genre: Pop
# Don't Let the Old Man In - Toby Keith - Genre: Country
# Selfish - Justin Timberlake - Genre: Pop
# I Remember Everything (feat. Kacey Musgraves) - Zach Bryan - Genre: Country
# Made For Me - Muni Long - Genre: R&B / Soul
# Fast Car - Luke Combs - Genre: Country
# Houdini - Dua Lipa - Genre: Pop
# Live Like You Were Dying - Tim McGraw - Genre: Country
# Where the Wild Things Are - Luke Combs - Genre: Country
# Lil Boo Thang - Paul Russell - Genre: Pop
# Training Season - Dua Lipa - New Release
# Save Me - Jelly Roll - Genre: Rap
# Fast Car - Tracy Chapman - Genre: Singer/Songwriter
# 16 CARRIAGES - Beyoncé - Genre: Country
# Until I Found You - Stephen Sanchez - Genre: Singer/Songwriter
# Yeah! (feat. Lil Jon & Ludacris) - USHER - Genre: R&B / Soul
# Cruel Summer - Taylor Swift - Genre: Pop
# Need a Favor - Jelly Roll - Genre: Country
# You Are the Reason - Calum Scott - Genre: Pop
# Sorrys & Ferraris - Polo G - New Release
# Three Little Birds - Bob Marley & The Wailers - Genre: Reggae
# Spicy Margarita - Jason Derulo & Michael Bublé - Genre: Pop
# Powerful Women - Pitbull & Dolly Parton - New Release
# White Horse - Chris Stapleton - Genre: Country
# Save Me (with Lainey Wilson) - Jelly Roll - Genre: Country
# Thinkin’ Bout Me - Morgan Wallen - Genre: Country
# Murder On the Dancefloor (Radio Edit) - Sophie Ellis-Bextor - Genre: Dance
# Country's Cool Again - Lainey Wilson - New Release
# Should've Been a Cowboy - Toby Keith - Genre: Country
# Good Day - Forrest Frank - Genre: Christian & Gospel
# What Was I Made For? (From The Motion Picture "Barbie") - Billie Eilish - Genre: Alternative
# Water - Tyla - Genre: Pop
# Until I Found You (Em Beihold Version) - Stephen Sanchez & Em Beihold - Genre: Singer/Songwriter
# Spin You Around (1/24) - Morgan Wallen - Genre: Country
# Wildflowers and Wild Horses (Single Version) - Lainey Wilson - Genre: Country
# In Case You Didn't Know - Brett Young - Genre: Country
# A Country Boy Can Survive - Hank Williams, Jr. - Genre: Country
# Hard to Love - Lee Brice - Genre: Country
# Lovin On Me - Jack Harlow - Genre: Hip-Hop / Rap
                          "genre": genres})
presis_df
# Out:
#                title                            artist               genre
# 0     TEXAS HOLD 'EM                           Beyoncé      Genre: Country
# 1   Beautiful Messes  Hillary Scott & The Scott Family      Genre: Country
# 2       Lose Control                       Teddy Swims          Genre: Pop
# 3   Beautiful Things                      Benson Boone          Genre: Pop
# 4            Flowers                       Miley Cyrus          Genre: Pop
# ..               ...                               ...                 ...
# 95  Leave a Light On                        Papa Roach    Genre: Hard Rock
# 96  ...Ready For It?                      Taylor Swift          Genre: Pop
# 97       The Painter                      Cody Johnson      Genre: Country
# 98   Scared To Start                   Michael Marcagi  Genre: Alternative
# 99         Unwritten               Natasha Bedingfield          Genre: Pop
#
# [100 rows x 3 columns]

# %%
import re
from datetime import datetime

if not song_elements:
    print("No song elements found. Please check if the website structure has changed.")
    exit()

data = []
for i, element in enumerate(song_elements):
    title = element.find('cite', class_='title').text.strip()
    artist = element.find('em', class_='artist').text.strip()

    # Extracting genre
    genre = "Genre not found"
    ul_tag = element.find('ul')
    if ul_tag:
        for li_tag in ul_tag.find_all('li'):
            if 'Genre' in li_tag.text:
                genre = li_tag.text.strip().replace('Genre:', '')
                break
                
    # Extracting release date using regular expression
    release_date_text = ""
    release_date_match = re.search(r'Release Date: (\w+ \d{1,2}, \d{4})', element.get_text())
    if release_date_match:
        release_date_text = release_date_match.group(1)
        
        # Convert release date to date format
        release_date = datetime.strptime(release_date_text, "%B %d, %Y").strftime("%d/%m/%Y")

    data.append([title, artist, genre, release_date])

df = pd.DataFrame(data, columns=['title', 'artist', 'genre', 'release_date'])
display(df)
# Out:
#                title                            artist         genre  \
# 0     TEXAS HOLD 'EM                           Beyoncé       Country
# 1   Beautiful Messes  Hillary Scott & The Scott Family       Country
# 2       Lose Control                       Teddy Swims           Pop
# 3   Beautiful Things                      Benson Boone           Pop
# 4            Flowers                       Miley Cyrus           Pop
# ..               ...                               ...           ...
# 95  Leave a Light On                        Papa Roach     Hard Rock
# 96  ...Ready For It?                      Taylor Swift           Pop
# 97       The Painter                      Cody Johnson       Country
# 98   Scared To Start                   Michael Marcagi   Alternative
# 99         Unwritten               Natasha Bedingfield           Pop
#
#    release_date
# 0    11/02/2024
# 1    08/07/2016
# 2    23/06/2023
# 3    19/01/2024
# 4    12/01/2023
# ..          ...
# 95   08/04/2022
# 96   01/01/2017
# 97   11/08/2023
# 98   12/01/2024
# 99   06/09/2004
#
# [100 rows x 4 columns]

# %% [markdown]
# # Lab | Web Scraping Single Page (GNOD part 2)¶

# %%
import random

# %%
# Recommend function for a random song if the input song is found in the DataFrame
def recommend_song(song_title):
    # Check if the song is in the DataFrame (case insensitive)
    if df['title'].str.lower().str.contains(song_title.lower()).any():
        # Get a random index that is not the index of the input song
        random_index = df[df['title'].str.lower() != song_title.lower()].sample().index[0]
        # Get the random song and artist
        random_song = df.loc[random_index, 'title']
        random_artist = df.loc[random_index, 'artist']
        return f"Thank you for the input and now we recommend \"{random_song}\" by {random_artist}"
    else:
        return "Thank you for the input but we currently have no recommendation for this song."

# Loop to recommend songs for 5 times
for i in range(5):
    input_song = input("Enter a song title: ")
    recommendation = recommend_song(input_song)
    print(recommendation)
# Out:
# Enter a song title: flowers
# Thank you for the input and now we recommend "Scared To Start" by Michael Marcagi
# Enter a song title: Flowers
# Thank you for the input and now we recommend "Let's Go" by Key Glock
# Enter a song title: lose controls
# Thank you for the input but we currently have no recommendation for this song.
# Enter a song title: unwritten
# Thank you for the input and now we recommend "Scared To Start" by Michael Marcagi
# Enter a song title: the painter
# Thank you for the input and now we recommend "Sorrys & Ferraris" by Polo G

# %% [markdown]
# # Lab | Web Scraping Single Page (GNOD part 3)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("spotify.txt","r")
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
# Enter to Spotify

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
# we will use our 'first paid music' playlist as an example:
playlist = sp.user_playlist_tracks("spotify", "1TM3rECdFTc0R0tgiIf0oW")

# %%
# this one is biiiig!
playlist["total"]
# Out:
# 4690

# %%
# playlist['items'] contains the tracks on the playlist
# playlist['items']

# %%
# we could use the url to the next page which is provided...
playlist['next']
# Out:
# 'https://api.spotify.com/v1/playlists/1TM3rECdFTc0R0tgiIf0oW/tracks?offset=100&limit=100&additional_types=track'

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
all_tracks = get_playlist_tracks("1TM3rECdFTc0R0tgiIf0oW")
len(all_tracks)
# Out:
# 4690

# %%
import pandas as pd
from pandas import json_normalize

# %%
tracks2 = json_normalize(all_tracks)

# %%
tracks2
# Out:
#                   added_at  is_local primary_color  \
# 0     2022-03-12T12:22:16Z     False          None
# 1     2022-03-12T12:22:16Z     False          None
# 2     2022-03-12T12:22:16Z     False          None
# 3     2022-03-12T12:22:16Z     False          None
# 4     2022-03-12T12:22:16Z     False          None
# ...                    ...       ...           ...
# 4685  2024-01-16T11:15:02Z     False          None
# 4686  2024-01-16T11:17:23Z     False          None
# 4687  2024-02-02T20:25:33Z     False          None
# 4688  2024-02-15T21:15:28Z     False          None
# 4689  2024-02-19T00:47:28Z     False          None
#
#                       added_by.external_urls.spotify  \
# 0     https://open.spotify.com/user/ben.woody.cheval
# 1     https://open.spotify.com/user/ben.woody.cheval
# 2     https://open.spotify.com/user/ben.woody.cheval
# 3     https://open.spotify.com/user/ben.woody.cheval
# 4     https://open.spotify.com/user/ben.woody.cheval
# ...                                              ...
# 4685  https://open.spotify.com/user/ben.woody.cheval
# 4686  https://open.spotify.com/user/ben.woody.cheval
# 4687  https://open.spotify.com/user/ben.woody.cheval
# 4688  https://open.spotify.com/user/ben.woody.cheval
# 4689  https://open.spotify.com/user/ben.woody.cheval
#
#                                           added_by.href       added_by.id  \
# 0     https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
# 1     https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
# 2     https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
# 3     https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
# 4     https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
# ...                                                 ...               ...
# 4685  https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
# 4686  https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
# 4687  https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
# 4688  https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
# 4689  https://api.spotify.com/v1/users/ben.woody.cheval  ben.woody.cheval
#
#      added_by.type                   added_by.uri track.album.album_type  \
# 0             user  spotify:user:ben.woody.cheval                  album
# 1             user  spotify:user:ben.woody.cheval                  album
# 2             user  spotify:user:ben.woody.cheval                  album
# 3             user  spotify:user:ben.woody.cheval                  album
# 4             user  spotify:user:ben.woody.cheval                  album
# ...            ...                            ...                    ...
# 4685          user  spotify:user:ben.woody.cheval                  album
# 4686          user  spotify:user:ben.woody.cheval                  album
# 4687          user  spotify:user:ben.woody.cheval                  album
# 4688          user  spotify:user:ben.woody.cheval                  album
# 4689          user  spotify:user:ben.woody.cheval                  album
#
#                                     track.album.artists  ...  \
# 0     [{'external_urls': {'spotify': 'https://open.s...  ...
# 1     [{'external_urls': {'spotify': 'https://open.s...  ...
# 2     [{'external_urls': {'spotify': 'https://open.s...  ...
# 3     [{'external_urls': {'spotify': 'https://open.s...  ...
# 4     [{'external_urls': {'spotify': 'https://open.s...  ...
# ...                                                 ...  ...
# 4685  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4686  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4687  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4688  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4689  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                     track.id track.is_local  \
# 0     3l9eg9RtisizG12a1D6nZl          False
# 1     50M7nY1oQuNHecs0ahWAtI          False
# 2     2TTAPkrGQQOZkaUTUlt21Q          False
# 3     7BvcpEdO7PUDGGSER1S9LA          False
# 4     0VjIjW4GlUZAMYd2vXMi3b          False
# ...                      ...            ...
# 4685  6ucR4KfvsBFWCMVFDvyKKl          False
# 4686  241LK9hqfXJyWpQ7oClQSN          False
# 4687  6hF9etLMoADWLsoui5ejGW          False
# 4688  3vkQ5DAB1qQMYO4Mr9zJN6          False
# 4689  4dT9raTvZyaeUnNC3qdTXB          False
#
#                                        track.name track.popularity  \
# 0                                   Pretty Pimpin                0
# 1                                  I Need My Girl               68
# 2                                         Strange               48
# 3                                     Todeswalzer               36
# 4                                 Blinding Lights               93
# ...                                           ...              ...
# 4685                                    Apologize               75
# 4686             Goddamn Lonely Love - Remastered               48
# 4687                           Graveless yet Dead               19
# 4688  Gimme! Gimme! Gimme! (A Man After Midnight)               84
# 4689                        Snakes For The Divine               44
#
#                                       track.preview_url track.track  \
# 0                                                  None        True
# 1     https://p.scdn.co/mp3-preview/d566beee419ec326...        True
# 2     https://p.scdn.co/mp3-preview/8942abcf1bc1fe32...        True
# 3     https://p.scdn.co/mp3-preview/3cf49f28fa44b6bd...        True
# 4                                                  None        True
# ...                                                 ...         ...
# 4685                                               None        True
# 4686  https://p.scdn.co/mp3-preview/bc56f38acfadbd63...        True
# 4687  https://p.scdn.co/mp3-preview/ee6e043add10f082...        True
# 4688                                               None        True
# 4689  https://p.scdn.co/mp3-preview/285324aebe01327e...        True
#
#      track.track_number track.type                             track.uri  \
# 0                     1      track  spotify:track:3l9eg9RtisizG12a1D6nZl
# 1                    10      track  spotify:track:50M7nY1oQuNHecs0ahWAtI
# 2                     4      track  spotify:track:2TTAPkrGQQOZkaUTUlt21Q
# 3                     1      track  spotify:track:7BvcpEdO7PUDGGSER1S9LA
# 4                     9      track  spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# ...                 ...        ...                                   ...
# 4685                 16      track  spotify:track:6ucR4KfvsBFWCMVFDvyKKl
# 4686                 17      track  spotify:track:241LK9hqfXJyWpQ7oClQSN
# 4687                  1      track  spotify:track:6hF9etLMoADWLsoui5ejGW
# 4688                 13      track  spotify:track:3vkQ5DAB1qQMYO4Mr9zJN6
# 4689                  1      track  spotify:track:4dT9raTvZyaeUnNC3qdTXB
#
#      video_thumbnail.url
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# ...                  ...
# 4685                None
# 4686                None
# 4687                None
# 4688                None
# 4689                None
#
# [4690 rows x 40 columns]

# %%
artists_df2 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in tracks2.index:
    artists_for_song = json_normalize(tracks2.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks2.iloc[i]['track.id']         # we want to keep song_id, it is the sae for all artists
    artists_for_song['song_name']  = tracks2.iloc[i]['track.name']       # we want to keep song_name, it is the sae for all artists
    artists_for_song['popularity'] = tracks2.iloc[i]['track.popularity'] # same for popularity   
    artists_df2 = pd.concat([artists_df2, artists_for_song], axis=0)

# %%
artists_df2.head()
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/5gspAQIAH8n...  5gspAQIAH8nJUrMYgXjCJ2
# 0  https://api.spotify.com/v1/artists/2cCUtGK9sDU...  2cCUtGK9sDU2EoElnk0GNB
# 0  https://api.spotify.com/v1/artists/6guTJsgPymD...  6guTJsgPymDUVfqDJyz5UG
# 0  https://api.spotify.com/v1/artists/2ytfu1MWsf7...  2ytfu1MWsf763hCBQmaQr6
# 0  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...  1Xyo4u8uXC1ZmMpatF05PJ
#
#            name    type                                    uri  \
# 0     Kurt Vile  artist  spotify:artist:5gspAQIAH8nJUrMYgXjCJ2
# 0  The National  artist  spotify:artist:2cCUtGK9sDU2EoElnk0GNB
# 0   Galaxie 500  artist  spotify:artist:6guTJsgPymDUVfqDJyz5UG
# 0        Windir  artist  spotify:artist:2ytfu1MWsf763hCBQmaQr6
# 0    The Weeknd  artist  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
#
#                                external_urls.spotify                 song_id  \
# 0  https://open.spotify.com/artist/5gspAQIAH8nJUr...  3l9eg9RtisizG12a1D6nZl
# 0  https://open.spotify.com/artist/2cCUtGK9sDU2Eo...  50M7nY1oQuNHecs0ahWAtI
# 0  https://open.spotify.com/artist/6guTJsgPymDUVf...  2TTAPkrGQQOZkaUTUlt21Q
# 0  https://open.spotify.com/artist/2ytfu1MWsf763h...  7BvcpEdO7PUDGGSER1S9LA
# 0  https://open.spotify.com/artist/1Xyo4u8uXC1ZmM...  0VjIjW4GlUZAMYd2vXMi3b
#
#          song_name popularity
# 0    Pretty Pimpin          0
# 0   I Need My Girl         68
# 0          Strange         48
# 0      Todeswalzer         36
# 0  Blinding Lights         93

# %%
df_final2 = artists_df2[['song_name', 'name', 'song_id', 'popularity']]
df_final2
# Out:
#                                       song_name               name  \
# 0                                 Pretty Pimpin          Kurt Vile
# 0                                I Need My Girl       The National
# 0                                       Strange        Galaxie 500
# 0                                   Todeswalzer             Windir
# 0                               Blinding Lights         The Weeknd
# ..                                          ...                ...
# 1                                     Apologize        OneRepublic
# 0              Goddamn Lonely Love - Remastered  Drive-By Truckers
# 0                            Graveless yet Dead        Convocation
# 0   Gimme! Gimme! Gimme! (A Man After Midnight)               ABBA
# 0                         Snakes For The Divine       High On Fire
#
#                    song_id popularity
# 0   3l9eg9RtisizG12a1D6nZl          0
# 0   50M7nY1oQuNHecs0ahWAtI         68
# 0   2TTAPkrGQQOZkaUTUlt21Q         48
# 0   7BvcpEdO7PUDGGSER1S9LA         36
# 0   0VjIjW4GlUZAMYd2vXMi3b         93
# ..                     ...        ...
# 1   6ucR4KfvsBFWCMVFDvyKKl         75
# 0   241LK9hqfXJyWpQ7oClQSN         48
# 0   6hF9etLMoADWLsoui5ejGW         19
# 0   3vkQ5DAB1qQMYO4Mr9zJN6         84
# 0   4dT9raTvZyaeUnNC3qdTXB         44
#
# [4954 rows x 4 columns]
